# %% [markdown]
# <a href="https://colab.research.google.com/github/vkesarwani2005/Scientific-Calculator/blob/main/Experiment_4_and_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-eecaf78d-be33-44b4-bc7e-43291f985da2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eecaf78d-be33-44b4-bc7e-43291f985da2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install pandas==2.2.2

import pandas as pd

# %%
df = pd.read_csv('usa_rain_prediction_dataset_2024_2025.csv')

# %% [markdown]
# ##**Experiment 4**

# %%
# Number of rows and columns
print(f'Rows and columns: {df.shape}')

# First five rows
print(f'\nFirst five rows:\n{df.head()}')

# Size
print(f'\nSize: {df.size}')

# Number of missing values
print(f'\nMissing values:\n{df.isnull().sum()}')

# Sum, average, min, max of numerical columns
print(f'\nSummary statistics:\n{df.describe()}')
# Out:
# Rows and columns: (73100, 9)
#
# First five rows:
#          Date  Location  Temperature   Humidity  Wind Speed  Precipitation  \
# 0  2024-01-01  New York    87.524795  75.655455   28.379506       0.000000
# 1  2024-01-02  New York    83.259325  28.712617   12.436433       0.526995
# 2  2024-01-03  New York    80.943050  64.740043   14.184831       0.916884
# 3  2024-01-04  New York    78.097552  59.738984   19.444029       0.094134
# 4  2024-01-05  New York    37.059963  34.766784    3.689661       1.361272
#
#    Cloud Cover     Pressure  Rain Tomorrow
# 0    69.617966  1026.030278              0
# 1    41.606048   995.962065              0
# 2    77.364763   980.796739              1
# 3    52.541196   979.012163              0
# 4    85.584000  1031.790859              0
#
# Size: 657900
#
# Missing values:
# Date             0
# Location         0
# Temperature      0
# Humidity         0
# Wind Speed       0
# Precipitation    0
# Cloud Cover      0
# Pressure         0
# ...

# %% [markdown]
# ##**Experiment 5**

# %%
# Step 1: Install necessary libraries (if not already installed)
# !pip install pandas matplotlib seaborn

# Step 2: Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 3: Ensure that plots render correctly in Colab
# %matplotlib inline

# Step 4: Upload the dataset (manually in Colab)
from google.colab import files
uploaded = files.upload()

# Load the dataset (replace 'your_file.csv' with the actual file name)
import io
df = pd.read_csv(io.BytesIO(uploaded['usa_rain_prediction_dataset_2024_2025.csv']))

# Step 5: Select only numerical columns and plot the histogram
df.select_dtypes(include=['float64', 'int64']).hist(figsize=(10, 8), bins=20, color='skyblue', edgecolor='black')

plt.suptitle('Distribution of Numerical Features', size=16)
plt.show()
# Out:
# ...
#      <input type="file" id="files-5d6d1c8f-fcc5-408a-a102-e5f177469642" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5d6d1c8f-fcc5-408a-a102-e5f177469642">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
